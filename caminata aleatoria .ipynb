# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
caminador=0
caras=[1,-1]#aguila,sello
proba=[.5,.5]#probabilidad para aguila y sello
resultado= np.random.choice(caras,1000,p=proba)#funcion en la cual simulamos aventar 1000 veces la moneda y pones la proba y las caras

y=np.ones(len(np.cumsum(resultado)))
plt.plot(np.cumsum(resultado),)

# %%
plt.plot(np.cumsum(resultado))
plt.xlabel('tiempo')
plt.ylabel('distancia')

# %%
#ejercicio 2 
def walker():
    global x,y
    eleccion= random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion == 1:
        x-=1
    elif eleccion == 2:
        y+=1
    else:
        y-=1
    return [x,y]
x=0#inicia el caminador 
Y=0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    x += random.randint(-1,1)
    y += random.randint(-1,1)
    return [x,y]
x=0
y=0

Pos = np.zeros((2,1000))
for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()

plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(pos[0,-1],Pos[1,-1],'ro-')

# %%
X_0 = np.array([[0],[0]])
delta_X = np.random.uniform(-1,1,(2,100))

X = np.concatenate((X_0,np.cumsum(delta_X,axis=1)),axis=1)
rw= plt.plot(X[0],X[1],"ro-")

# %%
def walker():
    global x,y
    eleccion = random.randint(0,1)
    if eleccion < 0.40:
        x+=1
    elif eleccion < 0.60:
        x-=1
    elif eleccion < 0.8:
        y+=1
    else:
        y-=1
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x += np.random.normal(0,2000)
    y += random.gauss(0,2000)
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    r = random.uniform(0,1)
    if r < 0.01: # un 1% de probabilidad de tomar un paso grande
        x += np.random.normal(0,2000)
        y += random.gauss(0,2000) 
    else:
        x += np.random.normal(0,1)
        y += random.gauss(0,1)
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")
