# %% [markdown]
# $amortiguado$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint 
# %matplotlib inline

# %%
k = 3.0 
m = 1.0   
B = .5
def armonico(variables, t):
    x, y = variables
    return [y, -k * x / m - B / m * y]
inicial = [0.6, 0.4] # x= posicion , y =velocidad
tiempo = np.arange(0, 20, .01)
resultado = odeint(armonico, inicial, tiempo)

# %%
xx, yy = resultado.T

# %%
omega0 = k/m

# %%
plt.figure(figsize = (6,6))
plt.scatter(xx, yy/omega0, lw = 0, s = 3, cmap = 'viridis', c = xx)
plt.show

# %% [markdown]
# $sobreamortiguado$

# %%
k = .1 # Constante del muelle
m = 1.0   # Masa
B = .5

# %%
omega0 = k/m
Gamma = B/(2*m)

# %%
omega0**2, Gamma**2
# Out:
# (0.010000000000000002, 0.0625)

# %%
inicial = [0.6, 0.4] 
tiempo = np.arange(0, 20, .01)
resultado = odeint(armonico, inicial, tiempo)

# %%
xxA, yyA = resultado.T

# %%
plt.figure(figsize = (6,6))
plt.scatter(xx, yy/omega0, lw = 0, s = 3, cmap = 'viridis', c = xx)
plt.show()

# %% [markdown]
# $amortiguado....crítico$

# %%
k = np.sqrt(.0625) # Constante del muelle
m = 1.0   # Masa
B = .5

# %%
omega0 = k/m
Gamma = B/(2*m)

# %%
omega0**2, Gamma**2
# Out:
# (0.0625, 0.0625)

# %%
omega0**2 == Gamma**2
# Out:
# True

# %%
inicial = [0.6, 0.4] 
tiempo = np.arange(0, 20, .01)
resultado = odeint(armonico, inicial, tiempo)

# %%
xxC, yyC = resultado.T

# %%
plt.figure(figsize = (6,6))
plt.scatter(xx, yy/omega0, lw = 0, s = 3, cmap = 'viridis', c = xx)
plt.show()
